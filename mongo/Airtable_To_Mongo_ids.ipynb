# %% [markdown]
# Make sure all the entries in Airtable are also in Mongo, and updated with latest info

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import airtable
import joblib
from tqdm import tqdm

# %%
table_name = 'M00_Register'

# %%
with open('.attoken', 'r', encoding='utf-8') as infile:
    attoken = infile.read().strip()

# %%
# Older base
#base_id = "appsHVqTWtD7QXeQb"
base_id = "appnZn2NYRxLtEvsT"
at = airtable.Airtable(base_id, attoken)
chron_result = at.get(table_name)
# chron_result has keys: 'record' and 'offset'

# %%
chron_result['records']
# Out:
# [OrderedDict([('id', 'rec00iOFJrJ37XzQe'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0052'),
#                             ('full_text',
#                              'Austrian defeats. (GJ (W) 1849: Mar c.14. (P) Mar 14, in NRZ. N/t; n/s. (Tr) MECW 9:63-64. (++) Not in MEW. -♦ Context in 49:15.'),
#                             ('num_chron_refs', 0),
#                             ('written', '1849: Mar c.14.'),
#                             ('reg_section', 'E'),
#                             ('published', 'Mar 14, in NRZ. N/t; n/s.'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acadb2)'),
#                             ('ent_num', 52),
#                             ('more_info', 'Not in MEW. -♦ Context in 49:15.'),
#                             ('translation', 'MECW 9:63-64.'),
#                             ('title', 'Austrian defeats.'),
#                             ('lang_orig', ['German']),
#                             ('entry_num_start1', 63),
#                             ('entry_num', 62)]))]),
#  OrderedDict([('id', 'rec017SgNlUZEL0Ox'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0731'),
#                             ('full_text',
#                              'Session of the National Council. [G] (D) 1848: Nov 27. (P) Dec 1, in NRZ. N/t: n/s. (Tr) MECW 8:111 (“Sitting of...’’). (++) Not in MEW. ->48:82.'),
#                             ('num_chron_refs', 0),
#                             ('any_date', True),
#                             ('dated_day', '27'),
#                             ('reg_section', 'E'),
#                             ('published', 'Dec 1, in NRZ. N/t: n/s.'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acaeac)'),
#                             ('ent_num', 731),
#                             ('dated', '1848: Nov 27.'),
#                             ('month_combined', 'Nov'),
#                             ('more_info', 'Not in MEW. ->48:82.'),
#                             ('translation', 'MECW 8:111 (“Sitting of...’’).'),
#                             ('dated_month', 'Nov'),
#                             ('day_combined', '27'),
#                             ('dated_year', 1848),
#                             ('title', 'Session of the National Council.'),
#                             ('year_combined', '1848'),
#                             ('lang_orig', ['German']),
#                             ('year_final', '1848'),
#                             ('entry_num_start1', 764),
#                             ('entry_num', 763)]))]),
#  OrderedDict([('id', 'rec01QQh0ULzx2Yzh'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'M0868'),
#                             ('full_text',
#                              'A superannuated administration— Prospects of the coalition ministry, &c. [E] (D) 1853: Jan 11. (P) Jan 28, in NYDT, #3677, p. 3de. Signed. The “&c" in the title is the NYDT’s. (S) MECW 11:471. (++) In MEW 8:484-89. —Written by M in German; transd by E. —> 53:5.'),
#                             ('num_chron_refs', 1),
#                             ('any_date', True),
#                             ('dated_day', '11'),
#                             ('reg_section', 'M'),
#                             ('published',
#                              'Jan 28, in NYDT, #3677, p. 3de. Signed. The “&c" in the title is the NYDT’s.'),
#                             ('mongo_id', 'ObjectId(630af2b35e934cb195acb303)'),
#                             ('ent_num', 868),
#                             ('dated', '1853: Jan 11.'),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Jan'),
#                             ('more_info',
#                              'In MEW 8:484-89. —Written by M in German; transd by E. —> 53:5.'),
#                             ('dated_month', 'Jan'),
#                             ('day_combined', '11'),
#                             ('dated_year', 1853),
#                             ('title',
#                              'A superannuated administration— Prospects of the coalition ministry, &c.'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1853'),
#                             ('chron_refs_text', '["recWmsUFCmcgFiyTX"]'),
#                             ('sampled', 'true'),
#                             ('source', 'MECW 11:471.'),
#                             ('lang_orig', ['English']),
#                             ('type', ['Journalism']),
#                             ('chron_refs', ['reczMbJBdOBZ38amn']),
#                             ('year_final', '1853'),
#                             ('entry_num_start1', 1853),
#                             ('entry_num', 1852)]))]),
#  OrderedDict([('id', 'rec02BsFtAj3lUkgS'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0899'),
#                             ('full_text',
#                              'The war. [E| (W) 1855: by Aug 18. (P) Sep 1, in NYDT, #4483, p. 4de. Lead article; n/s. (++) This is a shortened version of the second part of #ME9, q.v. Neither MEW nor MECW includes this NYDT version. MECW (14:749 n.343) opines that abridgments and alterations were performed by the NYDT; it provides footnotes on variants in connection with #ME9. -> Context in 55:35.'),
#                             ('num_chron_refs', 0),
#                             ('written', '1855: by Aug 18.'),
#                             ('reg_section', 'E'),
#                             ('published',
#                              'Sep 1, in NYDT, #4483, p. 4de. Lead article; n/s.'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acaf6b)'),
#                             ('ent_num', 899),
#                             ('more_info',
#                              'This is a shortened version of the second part of #ME9, q.v. Neither MEW nor MECW includes this NYDT version. MECW (14:749 n.343) opines that abridgments and alterations were performed by the NYDT; it provides footnotes on variants in connection with #ME9. -> Context in 55:35.'),
#                             ('title', 'The war.'),
#                             ('lang_orig', ['English']),
#                             ('entry_num_start1', 936),
#                             ('entry_num', 935)]))]),
#  OrderedDict([('id', 'rec0394GVW5spqrcE'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0803'),
#                             ('full_text',
#                              '-------------. Instructions to executors. [EJ (D) 1894: Nov 14; n/t. (++) In MEW 39:507-9; title = ’’Engels to his executors.” —♦94:47.'),
#                             ('num_chron_refs', 0),
#                             ('reg_section', 'E'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acaeff)'),
#                             ('ent_num', 803),
#                             ('dated', '1894: Nov 14; n/t.'),
#                             ('more_info',
#                              'In MEW 39:507-9; title = ’’Engels to his executors.” —♦94:47.'),
#                             ('title',
#                              '-------------. Instructions to executors.'),
#                             ('lang_orig', ['English']),
#                             ('entry_num_start1', 837),
#                             ('entry_num', 836)]))]),
#  OrderedDict([('id', 'rec04mGG3Tcv08OI4'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0566'),
#                             ('full_text',
#                              'On the situation in the Crimea. (GJ Über die Situation in der Krim. (D) 1855: Mar 30. (P) Apr 2, in NOZ. N/s. (S) MEW 11:173-75. (Tr) MECW 14:136 (“The situation in ...’’). (++) This is an altered version of #E629. -> 55:16.'),
#                             ('num_chron_refs', 0),
#                             ('any_date', True),
#                             ('dated_day', '30'),
#                             ('reg_section', 'E'),
#                             ('published', 'Apr 2, in NOZ. N/s.'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acade8)'),
#                             ('ent_num', 566),
#                             ('dated', '1855: Mar 30.'),
#                             ('month_combined', 'Mar'),
#                             ('more_info',
#                              'This is an altered version of #E629. -> 55:16.'),
#                             ('translation',
#                              'MECW 14:136 (“The situation in ...’’).'),
#                             ('dated_month', 'Mar'),
#                             ('day_combined', '30'),
#                             ('dated_year', 1855),
#                             ('title', 'On the situation in the Crimea.'),
#                             ('german_title',
#                              'Über die Situation in der Krim.'),
#                             ('year_combined', '1855'),
#                             ('source', 'MEW 11:173-75.'),
#                             ('lang_orig', ['German']),
#                             ('year_final', '1855'),
#                             ('entry_num_start1', 588),
#                             ('entry_num', 587)]))]),
#  OrderedDict([('id', 'rec08fGsbK8YmwGD9'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0853'),
#                             ('full_text',
#                              'To the German Workers Educational Association in London. [G] An den Deutschen Bildungsverein für Arbeiter in London. (D) 1893: Dec 1; a note acknowledging birthday greetings. (S) MEW 22:414. (++) E addresses the “K.A.B.V.,” i.e.. Communist Workers Educational Association. -♦ 93:56.'),
#                             ('num_chron_refs', 0),
#                             ('reg_section', 'E'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acaf38)'),
#                             ('ent_num', 853),
#                             ('dated',
#                              '1893: Dec 1; a note acknowledging birthday greetings.'),
#                             ('more_info',
#                              'E addresses the “K.A.B.V.,” i.e.. Communist Workers Educational Association. -♦ 93:56.'),
#                             ('title',
#                              'To the German Workers Educational Association in London.'),
#                             ('german_title',
#                              'An den Deutschen Bildungsverein für Arbeiter in London.'),
#                             ('source', 'MEW 22:414.'),
#                             ('lang_orig', ['German']),
#                             ('entry_num_start1', 889),
#                             ('entry_num', 888)]))]),
#  OrderedDict([('id', 'rec09cZlzQHf02Nfb'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0158'),
#                             ('full_text',
#                              'Conciliationist debates. [G] Vereinbarungsdebatten. (D) 1848: July 4. (P) July 5, in NRZ. N/s. (S) MEW 5:169-74. (Tr) MECW 7:180 (“The agreement debates”). -> 48:44.'),
#                             ('num_chron_refs', 0),
#                             ('any_date', True),
#                             ('dated_day', '4'),
#                             ('reg_section', 'E'),
#                             ('published', 'July 5, in NRZ. N/s.'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acac0d)'),
#                             ('ent_num', 158),
#                             ('dated', '1848: July 4.'),
#                             ('month_combined', 'Jul'),
#                             ('translation',
#                              'MECW 7:180 (“The agreement debates”). -> 48:44.'),
#                             ('dated_month', 'Jul'),
#                             ('day_combined', '4'),
#                             ('dated_year', 1848),
#                             ('title', 'Conciliationist debates.'),
#                             ('german_title', 'Vereinbarungsdebatten.'),
#                             ('year_combined', '1848'),
#                             ('source', 'MEW 5:169-74.'),
#                             ('lang_orig', ['German']),
#                             ('year_final', '1848'),
#                             ('entry_num_start1', 171),
#                             ('entry_num', 170)]))]),
#  OrderedDict([('id', 'rec0DHBUf0L661kNG'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0894'),
#                             ('reprint',
#                              'ST/E61 (SW/H) 101. ( + + ) In MEW Register: #E903, “War in Hungary” 19:251-53. —Second in the series #E40, q.v. ->81:25.'),
#                             ('full_text',
#                              'The wages system. [E] (W) 1881: May 15-16. (P) May 21, in the Labour Standard. Lead article; n/s. (S) ST/E2 (ALS) 8. (Re) ST/E61 (SW/H) 101. ( + + ) In MEW Register: #E903, “War in Hungary” 19:251-53. —Second in the series #E40, q.v. ->81:25.'),
#                             ('num_chron_refs', 0),
#                             ('written', '1881: May 15-16.'),
#                             ('reg_section', 'E'),
#                             ('published',
#                              'May 21, in the Labour Standard. Lead article; n/s.'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acaf66)'),
#                             ('ent_num', 894),
#                             ('title', 'The wages system.'),
#                             ('source', 'ST/E2 (ALS) 8.'),
#                             ('lang_orig', ['English']),
#                             ('entry_num_start1', 931),
#                             ('entry_num', 930)]))]),
#  OrderedDict([('id', 'rec0EQj5YtHesgca9'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'M0450'),
#                             ('full_text',
#                              'Legal proceedings against the Neue Rheinische Zeitung. [G] Gerichtliche Untersuchung gegen die “Neue Rheinische Zeitung.” (D) 1848: July 6. (P) July 7, in NRZ. N/s. (S) MEW 5:175-77. (Tr) MECW 7:186; ST/M81 (Pad/4) 115 (“Judicial investigation of . . .”). -> 48:45.'),
#                             ('num_chron_refs', 1),
#                             ('any_date', True),
#                             ('dated_day', '6'),
#                             ('reg_section', 'M'),
#                             ('published', 'July 7, in NRZ. N/s.'),
#                             ('mongo_id', 'ObjectId(630af2b35e934cb195acb122)'),
#                             ('ent_num', 450),
#                             ('dated', '1848: July 6.'),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Jul'),
#                             ('translation',
#                              'MECW 7:186; ST/M81 (Pad/4) 115 (“Judicial investigation of . . .”). -> 48:45.'),
#                             ('dated_month', 'Jul'),
#                             ('day_combined', '6'),
#                             ('dated_year', 1848),
#                             ('title',
#                              'Legal proceedings against the Neue Rheinische Zeitung.'),
#                             ('german_title',
#                              'Gerichtliche Untersuchung gegen die “Neue Rheinische Zeitung.”'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1848'),
#                             ('chron_refs_text', '["recAbZ0gFhzVJd3Ob"]'),
#                             ('sampled', 'true'),
#                             ('source', 'MEW 5:175-77.'),
#                             ('lang_orig', ['German']),
#                             ('type', ['Journalism']),
#                             ('mew_vol', '5'),
#                             ('mew_pgs', '175-177'),
#                             ('mecw_vol', '7'),
#                             ('mecw_pgs', '186'),
#                             ('chron_refs', ['reclKiY3XJiIiOs0V']),
#                             ('year_final', '1848'),
#                             ('entry_num_start1', 1420),
#                             ('entry_num', 1419)]))]),
#  OrderedDict([('id', 'rec0HppfovZVGJ7Ht'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'M0090'),
#                             ('full_text',
#                              'Bonapartean victims and tools. |E| (W) 1856: c.Apr 1. (P) Apr 14. in NYDT, #4676, p. 4def. Lead article; n/s. (++) Both MEW and MECW give the People’s Paper version (#M325.5) only, annotating differences. ->56:15.'),
#                             ('num_chron_refs', 1),
#                             ('any_date', True),
#                             ('writing_start_month', 'Apr'),
#                             ('written', '1856: c.Apr 1.'),
#                             ('reg_section', 'M'),
#                             ('published',
#                              'Apr 14. in NYDT, #4676, p. 4def. Lead article; n/s.'),
#                             ('mongo_id', 'ObjectId(630af2b35e934cb195acb329)'),
#                             ('ent_num', 90),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Apr'),
#                             ('more_info',
#                              'Both MEW and MECW give the People’s Paper version (#M325.5) only, annotating differences. ->56:15.'),
#                             ('pub_day', '14'),
#                             ('writing_start_day', '1'),
#                             ('day_combined', '1'),
#                             ('pub_month', 'Apr'),
#                             ('pub_year', 1856),
#                             ('writing_start_year', 1856),
#                             ('title', 'Bonapartean victims and tools.'),
#                             ('writing_start_approx', 'true'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1856'),
#                             ('chron_refs_text', '["recyE774R74kEs0wY"]'),
#                             ('sampled', 'true'),
#                             ('lang_orig', ['English']),
#                             ('type', ['Journalism', 'Not in MEW']),
#                             ('mew_vol', 'NA'),
#                             ('mew_pgs', 'NA'),
#                             ('mecw_vol', 'NA'),
#                             ('mecw_pgs', 'NA'),
#                             ('chron_refs', ['recHud9g54xTBRUj6']),
#                             ('year_final', '1856'),
#                             ('entry_num_start1', 1052),
#                             ('entry_num', 1051)]))]),
#  OrderedDict([('id', 'rec0IMGB157lGyZbJ'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0183'),
#                             ('full_text',
#                              'Continental socialism. [E] (W) 1844: Sep c.20. (P) Oct 5, in the New Moral World. N/t. Signed: Anglo-German. (S) MEGA I, 4:337; MECW 4:212. (++)InMEW 2:507-8. —This short article mainly quotes a letter from Barmen, but the framing intro and conclusion were also prob by E. -> 44:39.'),
#                             ('num_chron_refs', 0),
#                             ('written', '1844: Sep c.20.'),
#                             ('reg_section', 'E'),
#                             ('published',
#                              'Oct 5, in the New Moral World. N/t. Signed: Anglo-German.'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acac29)'),
#                             ('ent_num', 183),
#                             ('more_info',
#                              'InMEW 2:507-8. —This short article mainly quotes a letter from Barmen, but the framing intro and conclusion were also prob by E. -> 44:39.'),
#                             ('title', 'Continental socialism.'),
#                             ('source', 'MEGA I, 4:337; MECW 4:212.'),
#                             ('lang_orig', ['English']),
#                             ('entry_num_start1', 195),
#                             ('entry_num', 194)]))]),
#  OrderedDict([('id', 'rec0JncTFma64u4wh'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'M0365'),
#                             ('full_text',
#                              '-------------. Introduction. [G] Einleitung. (W) 1857: Aug D to Sep M. (P/P) 1903: Mar, in the Neue Zeit, in a version ed by K. Kautsky; 1939, in the Grundrisse, q.v. (S) M: Grundrisse (ST/M46b) 3-31; MEW 13:615-42, where it is called Introduction [to the critique of political economy] [Einleitung zur Kritik der politischen Ökonomie]. (Tr) ST/ M21 (CCPO) 188; ST/M47 (Nicolaus) 81; ST/ M48 (McL.) 16. First trans was in ST/M20. (++) M originally wrote this as an intro to #M181, but replaced it with the pubd preface. It remained in his notebook unknown till 1902, pubd 1903. For a long time it was the only part of the Grundrisse to achieve publ. For more info, see the boxed "Guide.” -> 57:35, 40; 59:13.'),
#                             ('num_chron_refs', 3),
#                             ('any_date', True),
#                             ('writing_start_month', 'Aug'),
#                             ('written', '1857: Aug D to Sep M.'),
#                             ('reg_section', 'M'),
#                             ('posthumous',
#                              '1903: Mar, in the Neue Zeit, in a version ed by K. Kautsky; 1939, in the Grundrisse, q.v.'),
#                             ('mongo_id', 'ObjectId(630af2b35e934cb195acb0c3)'),
#                             ('ent_num', 365),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Aug'),
#                             ('more_info',
#                              'M originally wrote this as an intro to #M181, but replaced it with the pubd preface. It remained in his notebook unknown till 1902, pubd 1903. For a long time it was the only part of the Grundrisse to achieve publ. For more info, see the boxed "Guide.” -> 57:35, 40; 59:13.'),
#                             ('writing_start_day', 'D'),
#                             ('writing_end_day', 'M'),
#                             ('writing_end_month', 'Sep'),
#                             ('writing_end_year', 1857),
#                             ('translation',
#                              'ST/ M21 (CCPO) 188; ST/M47 (Nicolaus) 81; ST/ M48 (McL.) 16. First trans was in ST/M20.'),
#                             ('day_combined', 'D'),
#                             ('writing_start_year', 1857),
#                             ('title', '-------------. Introduction.'),
#                             ('german_title', 'Einleitung.'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1857'),
#                             ('chron_refs_text',
#                              '["reczR740ic142lyKt","recmKMkdy4FvflV1q","rec7QcDd2h3rxxJxp"]'),
#                             ('sampled', 'true'),
#                             ('source',
#                              'M: Grundrisse (ST/M46b) 3-31; MEW 13:61542, where it is called Introduction [to the critique of political economy] [Einleitung zur Kritik der politischen Ökonomie].'),
#                             ('lang_orig', ['German']),
#                             ('type', ['Article']),
#                             ('chron_refs',
#                              ['recRag01VSO4Dn1aH',
#                               'rec58tgnIedtc3tao',
#                               'rec3hlaUw1Bh6HXdn']),
#                             ('year_final', '1857'),
#                             ('entry_num_start1', 1335),
#                             ('entry_num', 1334)]))]),
#  OrderedDict([('id', 'rec0NepbkFEH9c1bS'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'ME0009'),
#                             ('full_text',
#                              'The Anglo-French war against Russia. [G] Der englisch-französische Krieg gegen Russland. (D) 1855: Aug 17, 18. (P) Aug 20, 21, in NOZ; in 2 installs. N/s. (S) MEW 11:493-97. (Tr) MECW 14:484. (++) An adaptation of the second part of this article was sent to the NYDT and became #E899. —* 55:35.'),
#                             ('num_chron_refs', 1),
#                             ('any_date', True),
#                             ('dated_day', '17'),
#                             ('reg_section', 'ME'),
#                             ('published',
#                              'Aug 20, 21, in NOZ; in 2 installs. N/s.'),
#                             ('mongo_id', 'ObjectId(630af2b45e934cb195acb44e)'),
#                             ('ent_num', 9),
#                             ('dated', '1855: Aug 17, 18.'),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Aug'),
#                             ('more_info',
#                              'An adaptation of the second part of this article was sent to the NYDT and became #E899. —* 55:35.'),
#                             ('pub_day', '20'),
#                             ('translation', 'MECW 14:484.'),
#                             ('dated_month', 'Aug'),
#                             ('day_combined', '17'),
#                             ('dated_year', 1855),
#                             ('pub_month', 'Aug'),
#                             ('pub_year', 1855),
#                             ('title', 'The Anglo-French war against Russia.'),
#                             ('german_title',
#                              'Der englisch-französische Krieg gegen Russland.'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1855'),
#                             ('chron_refs_text', '["recq36BxVlsnFwr8s"]'),
#                             ('sampled', 'true'),
#                             ('source', 'MEW 11:493-97.'),
#                             ('lang_orig', ['German']),
#                             ('type', ['Journalism']),
#                             ('chron_refs', ['recUci3K2X4SaOQhn']),
#                             ('year_final', '1855'),
#                             ('entry_num_start1', 1991),
#                             ('entry_num', 1990)]))]),
#  OrderedDict([('id', 'rec0O1GnggwRpwdhH'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0721'),
#                             ('full_text',
#                              'St. Helena. Fragment. [G] Sankt Helena. Fragment. [Poem] (W) 1840: Nov. (P) Nov, in TfD, no. 191. Signed: Friedrich Oswald. (S) MEW Eb.2:104. (Tr) MECW 2:131. ->40:16.'),
#                             ('num_chron_refs', 0),
#                             ('written', '1840: Nov.'),
#                             ('reg_section', 'E'),
#                             ('published',
#                              'Nov, in TfD, no. 191. Signed: Friedrich Oswald.'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acaea0)'),
#                             ('ent_num', 721),
#                             ('translation', 'MECW 2:131. ->40:16.'),
#                             ('title', 'St. Helena. Fragment.'),
#                             ('german_title', 'Sankt Helena. Fragment. [Poem]'),
#                             ('source', 'MEW Eb.2:104.'),
#                             ('lang_orig', ['German']),
#                             ('entry_num_start1', 753),
#                             ('entry_num', 752)]))]),
#  OrderedDict([('id', 'rec0OcqIgjkuykaju'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0346'),
#                             ('full_text',
#                              'Greetings to the socialists of Sicily. (Fr) (W) 1894: Sep 26; sent by E to La Giustizia Sociale (which, however, was suppressed before printing it). N/t. According to one source, E’s letter itself was dated Sep 26. (P) 1895: June 30, in La Riscossa Socialista (Palermo), under the heading: “I socialisti stranieri ai lavorati di Sicilia./ Inghilterra” [Foreign socialists to the workingmen of Sicily./ England). —Aug 1, in the Arbeiter-Ztg (Vienna), in German transd from Italian, bit shortened. —Aug 16, in Critica Sociale, in Italian, headed “L’ultima parola all’ltalia” (The last word to Italy]—i.e., Engels’, since he had just died. (S) ST/ME17 (Cor/It) 561, for the French original; 562, for the Italian version; ST/ME58 (Scr/It) 178, Italian only. (++) In MEW 22:476-77; conferred title as at head; transd from the Italian of Critica Sociale, but footnotes give variations from the original French ms. -> 94:36:95:35,37.'),
#                             ('num_chron_refs', 0),
#                             ('written',
#                              '1894: Sep 26; sent by E to La Giustizia Sociale (which, however, was suppressed before printing it). N/t. According to one source, E’s letter itself was dated Sep 26.'),
#                             ('reg_section', 'E'),
#                             ('published',
#                              '1895: June 30, in La Riscossa Socialista (Palermo), under the heading: “I socialisti stranieri ai lavorati di Sicilia./ Inghilterra” [Foreign socialists to the workingmen of Sicily./ England). —Aug 1, in the Arbeiter-Ztg (Vienna), in German transd from Italian, bit shortened. —Aug 16, in Critica Sociale, in Italian, headed “L’ultima parola all’ltalia” (The last word to Italy]—i.e., Engels’, since he had just died.'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acace7)'),
#                             ('ent_num', 346),
#                             ('more_info',
#                              'In MEW 22:476-77; conferred title as at head; transd from the Italian of Critica Sociale, but footnotes give variations from the original French ms. -> 94:36:95:35,37.'),
#                             ('title',
#                              'Greetings to the socialists of Sicily.'),
#                             ('source',
#                              'ST/ME17 (Cor/It) 561, for the French original; 562, for the Italian version; ST/ME58 (Scr/It) 178, Italian only.'),
#                             ('lang_orig', ['French']),
#                             ('entry_num_start1', 363),
#                             ('entry_num', 362)]))]),
#  OrderedDict([('id', 'rec0OdjvY2Hqvy60u'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0153'),
#                             ('full_text',
#                              'Company drill. [E] (W) 1861: Apr M. (P) Apr 20, in the Volunteer Journal. Signed: F.E. (S) ST/E15 (EMC) 29. (++) In MEW 15:270—74. -*61:19.'),
#                             ('num_chron_refs', 0),
#                             ('written', '1861: Apr M.'),
#                             ('reg_section', 'E'),
#                             ('published',
#                              'Apr 20, in the Volunteer Journal. Signed: F.E.'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acac08)'),
#                             ('ent_num', 153),
#                             ('more_info', 'In MEW 15:270—74. -*61:19.'),
#                             ('title', 'Company drill.'),
#                             ('source', 'ST/E15 (EMC) 29.'),
#                             ('lang_orig', ['English']),
#                             ('entry_num_start1', 166),
#                             ('entry_num', 165)]))]),
#  OrderedDict([('id', 'rec0Ux3QDvJnsbdo2'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'M0404'),
#                             ('full_text',
#                              'Indifference to politics. [It] L’indifferenza in materia politica. (W) 1872-1873: Dec to Jan; see note below. (D) 1873: Jan. (P) Dec, in Almanacco Repubblicano per J’anno 1874 (Lodi) ed by E. Bignami. (For more info, see #E538.) Signed. (S) ST/ME58 (Scr/It) 98. (Tr) ST/ME3 (AAS) 94; ST/M40 (FLA) 327 (“Political indifferentism”). (++) In MEW 18:299-304. Note that MEW 18 gives three different dates for (W): end of 1872 to Jan A (p. 304); Dec D to Jan A (p. 740); Nov-Dec 1872 (p. 793). -> 72:67; 73:9, 58.'),
#                             ('num_chron_refs', 3),
#                             ('any_date', True),
#                             ('writing_start_month', 'Dec'),
#                             ('written',
#                              ': end of 1872 to Jan A (p. 304); Dec D to Jan A (p. 740); NovDec 1872 (p. 793). -> 72:67; 73:9, 58.'),
#                             ('reg_section', 'M'),
#                             ('published',
#                              'Dec, in Almanacco Repubblicano per J’anno 1874 (Lodi) ed by E. Bignami. (For more info, see #E538.) Signed.'),
#                             ('mongo_id', 'ObjectId(630af2b35e934cb195acb0ef)'),
#                             ('ent_num', 404),
#                             ('dated', '1873: Jan.'),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Dec'),
#                             ('more_info',
#                              'In MEW 18:299-304. Note that MEW 18 gives three different dates for'),
#                             ('writing_end_month', 'Jan'),
#                             ('writing_end_year', 1873),
#                             ('translation',
#                              'ST/ME3 (AAS) 94; ST/M40 (FLA) 327 (“Political indifferentism”).'),
#                             ('dated_month', 'Jan'),
#                             ('dated_year', 1873),
#                             ('writing_start_year', 1872),
#                             ('title', 'Indifference to politics.'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1872'),
#                             ('chron_refs_text',
#                              '["receMg3cgMGsOnT7F","recQfIyDFjVRhIRkW","recdTFaMCyrxmMbZx"]'),
#                             ('sampled', 'true'),
#                             ('source', 'ST/ME58 (Scr/It) 98.'),
#                             ('lang_orig', ['Italian']),
#                             ('type', ['Journalism']),
#                             ('italian_title',
#                              '[It] L’indifferenza in materia politica.'),
#                             ('chron_refs',
#                              ['recube7hJsIf9z41C',
#                               'recP3dtj2XcBDPeDw',
#                               'recgWAJLkGDyJANlH']),
#                             ('year_final', '1872'),
#                             ('entry_num_start1', 1374),
#                             ('entry_num', 1373)]))]),
#  OrderedDict([('id', 'rec0VkMj1o6XC5oRO'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'ST0062'),
#                             ('full_text',
#                              'Ryazanov, D. “Karl Marx und Friedrich Engels über die Polenfrage." [In:] Archiv für die Gesch. des Sozialismus u. d. Arbeiterbewegung, Bd. 6,1916.'),
#                             ('num_chron_refs', 0),
#                             ('reg_section', 'ST'),
#                             ('mongo_id', 'ObjectId(630af2b45e934cb195acb499)'),
#                             ('ent_num', 62),
#                             ('auth', '["reccmOVIBsIWVYqle"]'),
#                             ('title',
#                              'Ryazanov, D. “Karl Marx und Friedrich Engels über die Polenfrage." [In:] Archiv für die Gesch. des Sozialismus u. d. Arbeiterbewegung, Bd. 6,1916.'),
#                             ('year_combined', '1916'),
#                             ('year_final', '1916'),
#                             ('entry_num_start1', 2247),
#                             ('entry_num', 2246)]))]),
#  OrderedDict([('id', 'rec0XCDYAMx9Zidbw'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'M0272'),
#                             ('reprint',
#                              'ST/ME5 (AB) 109 (“The elections in England [etc.]"); ST/ ME44b (OB) 351 (do.); ST/M102 (SFE) 256 (“Tories and Whigs").'),
#                             ('full_text',
#                              'The elections—Tories and Whigs. [E] (W) 1852: Aug 2. (D) Aug 6. (P) Aug 21, in NYDT, #3540, p. 6ab, under the rubric “England." —Oct 2, in PP, adapted version. (S) MECW 11:327. (Re) ST/ME5 (AB) 109 (“The elections in England [etc.]"); ST/ ME44b (OB) 351 (do.); ST/M102 (SFE) 256 (“Tories and Whigs"). (++) In MEW 8:336-41. —First article written by M for the NYDT; transd into English by E. This and #M138 were written as one article, divided by E. —>52:33,43.'),
#                             ('num_chron_refs', 2),
#                             ('any_date', True),
#                             ('writing_start_month', 'Aug'),
#                             ('written', '1852: Aug 2.'),
#                             ('dated_day', '6'),
#                             ('reg_section', 'M'),
#                             ('published',
#                              'Aug 21, in NYDT, #3540, p. 6ab, under the rubric “England." —Oct 2, in PP, adapted version.'),
#                             ('mongo_id', 'ObjectId(630af2b35e934cb195acb058)'),
#                             ('ent_num', 272),
#                             ('dated', 'Aug 6.'),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Aug'),
#                             ('more_info',
#                              'In MEW 8:33641. —First article written by M for the NYDT; transd into English by E. This and #M138 were written as one article, divided by E. —>52:33,43.'),
#                             ('writing_start_day', '2'),
#                             ('dated_month', 'Aug'),
#                             ('day_combined', '2'),
#                             ('dated_year', 1852),
#                             ('writing_start_year', 1852),
#                             ('title', 'The elections—Tories and Whigs.'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1852'),
#                             ('chron_refs_text',
#                              '["recgvpKefpHSqmvXC","recV1n02TuWUA7P1Q"]'),
#                             ('sampled', 'true'),
#                             ('source', 'MECW 11:327.'),
#                             ('lang_orig', ['English']),
#                             ('type', ['Journalism']),
#                             ('mecw_vol', '11'),
#                             ('mecw_pgs', '327'),
#                             ('chron_refs',
#                              ['recGZuqcI7cDjJbzc', 'recCmkpcOLij221Ar']),
#                             ('year_final', '1852'),
#                             ('entry_num_start1', 1239),
#                             ('entry_num', 1238)]))]),
#  OrderedDict([('id', 'rec0XIgba8D8IEYFO'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'STME0072'),
#                             ('full_text',
#                              'Writings on the Paris Commune. Ed by Hal Draper. NY: Monthly Review Pr., 1971. —Foreword by the editor.'),
#                             ('num_chron_refs', 0),
#                             ('reg_section', 'STME'),
#                             ('mongo_id', 'ObjectId(630af2b45e934cb195acb5ab)'),
#                             ('ent_num', 72),
#                             ('more_info', 'Foreword by the editor.'),
#                             ('title',
#                              'Writings on the Paris Commune. Ed by Hal Draper. NY: Monthly Review Pr., 1971.'),
#                             ('entry_num_start1', 2560),
#                             ('entry_num', 2559)]))]),
#  OrderedDict([('id', 'rec0Xj5k40HvEQTmF'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'STME0048.5'),
#                             ('full_text',
#                              'On literature and art. Moscow: Prog Pub, 1978, © 1976.'),
#                             ('num_chron_refs', 0),
#                             ('reg_section', 'STME'),
#                             ('mongo_id', 'ObjectId(630af2b45e934cb195acb590)'),
#                             ('ent_num', 48.5),
#                             ('title',
#                              'On literature and art. Moscow: Prog Pub, 1978, © 1976.'),
#                             ('entry_num_start1', 2532),
#                             ('entry_num', 2531)]))]),
#  OrderedDict([('id', 'rec0aO36deFnDA1lq'),
#               ('createdTime', '2022-10-03T20:45:53.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'STME0040.1'),
#                             ('full_text',
#                              '(a) Marx and Engels on Malthus. Selections from the writings of Marx and Engels dealing with the theories of Thomas Robert Malthus. Ed with intro essay and notes by Ronald L. Meek. Translations from the German by Dorothea L. Meek and Ronald L. Meek. L&W, 1953; Int’l Pub, 1954; New Delhi: People’s Pub House, 1956.190p. (b) Marx and Engels on the population bomb. —A “2nd edn,” with the same subtitle, with added foreword by Steve Weissman, pubd Berkeley: Ramparts Pr., 1971. 215p. —Boldly retitled in defiance of the fact that M&E were not writing about the “population bomb.”'),
#                             ('num_chron_refs', 0),
#                             ('reg_section', 'STME'),
#                             ('mongo_id', 'ObjectId(630af2b45e934cb195acb587)'),
#                             ('ent_num', 40),
#                             ('more_info',
#                              'A “2nd edn,” with the same subtitle, with added foreword by Steve Weissman, pubd Berkeley: Ramparts Pr., 1971. 215p.\n\nBoldly retitled in defiance of the fact that M&E were not writing about the “population bomb.”'),
#                             ('title',
#                              'Marx and Engels on the population bomb.'),
#                             ('entry_num_start1', 2519),
#                             ('entry_num', 2518)]))]),
#  OrderedDict([('id', 'rec0bIEdYKVZN4wLd'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'M0048'),
#                             ('full_text',
#                              'Appeal [of the Rhineland District Committee of the Democrats on tax refusal]. |G| Aufforderung des Rheinischen Kreisausschusses der Demokraten zur Steuerverweigerung. (D) 1848: Nov 18. (P) Nov 19, in NRZ. N/t, except for small heading “Aufruf” [Appeal]. Signed, for the comm, by M and two others. (S) MEW 6:33; titled as at head. (Tr) MECW 8:41; ST/ME54 (R48/49) 168. -> 48:80.'),
#                             ('num_chron_refs', 1),
#                             ('any_date', True),
#                             ('dated_day', '18'),
#                             ('reg_section', 'M'),
#                             ('published',
#                              'Nov 19, in NRZ. N/t, except for small heading “Aufruf” [Appeal]. Signed, for the comm, by M and two others.'),
#                             ('mongo_id', 'ObjectId(630af2b35e934cb195acb143)'),
#                             ('ent_num', 48),
#                             ('dated', '1848: Nov 18.'),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Nov'),
#                             ('pub_day', '19'),
#                             ('translation',
#                              'MECW 8:41; ST/ME54 (R48/49) 168. -> 48:80.'),
#                             ('dated_month', 'Nov'),
#                             ('day_combined', '18'),
#                             ('dated_year', 1848),
#                             ('pub_month', 'Nov'),
#                             ('pub_year', 1848),
#                             ('title',
#                              'Appeal [of the Rhineland District Committee of the Democrats on tax refusal].'),
#                             ('german_title',
#                              'Aufforderung des Rheinischen Kreisausschusses der Demokraten zur Steuerverweigerung.'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1848'),
#                             ('chron_refs_text', '["rec411j66gJfhqGPI"]'),
#                             ('sampled', 'true'),
#                             ('source', 'MEW 6:33; titled as at head.'),
#                             ('lang_orig', ['German']),
#                             ('type', ['Journalism']),
#                             ('mecw_vol', '8'),
#                             ('mecw_pgs', '41'),
#                             ('chron_refs', ['recxl1MYIbBxPUL4q']),
#                             ('year_final', '1848'),
#                             ('entry_num_start1', 1008),
#                             ('entry_num', 1007)]))]),
#  OrderedDict([('id', 'rec0bzxRLmPl0YqSJ'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'M0596'),
#                             ('full_text',
#                              'On the activity of the Alliance of the Socialist Democracy. (Report of speech at the commission of inquiry, London Conference, September 18, 1871.) [Fr] (W) 1871: Sep 18, evening, M gave this report to the commission established by the conference; this record was made by E in French. N/t. (++) In MEW 17:411. —>71:47.'),
#                             ('num_chron_refs', 1),
#                             ('any_date', True),
#                             ('writing_start_month', 'Sep'),
#                             ('written',
#                              '1871: Sep 18, evening, M gave this report to the commission established by the conference; this record was made by E in French. N/t.'),
#                             ('reg_section', 'M'),
#                             ('mongo_id', 'ObjectId(630af2b35e934cb195acb1cc)'),
#                             ('ent_num', 596),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Sep'),
#                             ('more_info', 'In MEW 17:411. —>71:47.'),
#                             ('writing_start_day', '18'),
#                             ('day_combined', '18'),
#                             ('writing_start_year', 1871),
#                             ('title',
#                              'On the activity of the Alliance of the Socialist Democracy. (Report of speech at the commission of inquiry, London Conference, September 18, 1871.)'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1871'),
#                             ('chron_refs_text', '["recrgnmPeMPgao6P2"]'),
#                             ('sampled', 'true'),
#                             ('lang_orig', ['French']),
#                             ('type', ['Speeches/Addresses']),
#                             ('chron_refs', ['rec0Oty17OSuKimCg']),
#                             ('year_final', '1871'),
#                             ('entry_num_start1', 1573),
#                             ('entry_num', 1572)]))]),
#  OrderedDict([('id', 'rec0ccbSTy0uf2mKl'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0120'),
#                             ('full_text',
#                              'The capture of Bomarsund. [First article] [E] (W) 1854: Aug 21. (P) Sep 4, in NYDT, #4174, p. 4de. Lead article; n/s. (S) MECW 13:379. (++) In MEW 10:421-25. —>54:40.'),
#                             ('num_chron_refs', 0),
# ...
#                             ('year_final', '1945'),
#                             ('entry_num_start1', 2244),
#                             ('entry_num', 2243)]))]),
#  OrderedDict([('id', 'rec264zfIP44cCmje'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'ME0124'),
#                             ('full_text',
#                              'Public Prosecutor Hecker questions people who had attended the Worringen meeting. [G] (W) By M/E; authorship not ascribed. (D) 1848: Sep 24. (P) Sep 26, in NRZ. N/t; n/s. (Tr) MECW 7:451. (++) Not in MEW. ->48:65.'),
#                             ('num_chron_refs', 1),
#                             ('any_date', True),
#                             ('written', 'By M/E; authorship not ascribed.'),
#                             ('dated_day', '24'),
#                             ('reg_section', 'ME'),
#                             ('published', 'Sep 26, in NRZ. N/t; n/s.'),
#                             ('mongo_id', 'ObjectId(630af2b45e934cb195acb3b4)'),
#                             ('ent_num', 124),
#                             ('dated', '1848: Sep 24.'),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Sep'),
#                             ('more_info', 'Not in MEW. ->48:65.'),
#                             ('pub_day', '26'),
#                             ('translation', 'MECW 7:451.'),
#                             ('dated_month', 'Sep'),
#                             ('day_combined', '24'),
#                             ('dated_year', 1848),
#                             ('pub_month', 'Sep'),
#                             ('pub_year', 1848),
#                             ('title',
#                              'Public Prosecutor Hecker questions people who had attended the Worringen meeting.'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1848'),
#                             ('chron_refs_text', '["recoDdUSAis6dYwVJ"]'),
#                             ('sampled', 'true'),
#                             ('lang_orig', ['German']),
#                             ('type',
#                              ['Journalism', 'Ascribed to Engels in MEGA2']),
#                             ('chron_refs', ['recQ2xBepS4kqkEK3']),
#                             ('year_final', '1848'),
#                             ('entry_num_start1', 2106),
#                             ('entry_num', 2105)]))]),
#  OrderedDict([('id', 'rec26LeezJnrwF5Y3'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'ME0150'),
#                             ('reprint',
#                              '%ST/M28 (EQ) 58; all of article save last part. —%ST/ME56 (RME) 157. —%ST/ M58 (OCM) 65 ("The East India question"). —%ST/M3 (AI) 61 (do.).'),
#                             ('full_text',
#                              'The Russo-Turkish difficulty—Ducking and dodging of the British cabinet— Nesselrode’s last note—East-India question. |E] (D) 1853: July 12. (P) July 25. in NYDT, #3828, p. 5def, under the rubric "Great Britain." Signed. (S) MECW 12:192. (Re) %ST/M28 (EQ) 58; all of article save last part. —%ST/ME56 (RME) 157. —%ST/ M58 (OCM) 65 ("The East India question"). —%ST/M3 (AI) 61 (do.). (++) In MEW 9:195-203. ->53:26.'),
#                             ('num_chron_refs', 1),
#                             ('any_date', True),
#                             ('dated_day', '12'),
#                             ('reg_section', 'ME'),
#                             ('published',
#                              'July 25. in NYDT, #3828, p. 5def, under the rubric "Great Britain." Signed.'),
#                             ('mongo_id', 'ObjectId(630af2b45e934cb195acb3d1)'),
#                             ('ent_num', 150),
#                             ('dated', '1853: July 12.'),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Jul'),
#                             ('more_info', 'In MEW 9:195-203. ->53:26.'),
#                             ('pub_day', '25'),
#                             ('dated_month', 'Jul'),
#                             ('day_combined', '12'),
#                             ('dated_year', 1853),
#                             ('pub_month', 'Jul'),
#                             ('pub_year', 1853),
#                             ('title',
#                              'The Russo-Turkish difficulty—Ducking and dodging of the British cabinet— Nesselrode’s last note—East-India question.'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1853'),
#                             ('chron_refs_text', '["recuHjPXF9XxZBNnu"]'),
#                             ('sampled', 'true'),
#                             ('source', 'MECW 12:192.'),
#                             ('lang_orig', ['English']),
#                             ('type', ['Journalism']),
#                             ('chron_refs', ['recThAda7d3xrwQjj']),
#                             ('year_final', '1853'),
#                             ('entry_num_start1', 2132),
#                             ('entry_num', 2131)]))]),
#  OrderedDict([('id', 'rec28QskIeUBvkNjT'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'M0182'),
#                             ('full_text',
#                              '-------------. Part of an early draft. [G] Fragment der Urtext.... (W) 1858: betw Aug A and Nov M; in two undated notebooks. (P/P) 1939 and 1953, with #M361, q.v. (S) In M: Grundrisse (ST/ M46b), 871-947. (++) For more info, see ‘‘Guide to ... Grundrisse,” p. 48. -> 58:36.'),
#                             ('num_chron_refs', 1),
#                             ('any_date', True),
#                             ('writing_start_month', 'Aug'),
#                             ('written',
#                              '1858: betw Aug A and Nov M; in two undated notebooks.'),
#                             ('reg_section', 'M'),
#                             ('posthumous', '1939 and 1953, with #M361, q.v.'),
#                             ('mongo_id', 'ObjectId(630af2b35e934cb195acaff1)'),
#                             ('ent_num', 182),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Aug'),
#                             ('more_info',
#                              'For more info, see ‘‘Guide to ... Grundrisse,” p. 48. -> 58:36.'),
#                             ('writing_start_day', 'A'),
#                             ('writing_end_day', 'M'),
#                             ('writing_end_month', 'Nov'),
#                             ('writing_end_year', 1858),
#                             ('notes', 'Grundrisse pdf, pgs 891 - 967'),
#                             ('day_combined', 'A'),
#                             ('writing_start_year', 1858),
#                             ('title',
#                              'Contribution to the critique of political economy. Part of an early draft.'),
#                             ('german_title', 'Fragment der Urtext....'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1858'),
#                             ('chron_refs_text', '["recanKEu7iZd4zHss"]'),
#                             ('sampled', 'true'),
#                             ('source',
#                              'In M: Grundrisse (ST/ M46b), 871-947.'),
#                             ('lang_orig', ['German']),
#                             ('type', ['Draft']),
#                             ('chron_refs', ['reczgCkFDaE7jAGwa']),
#                             ('year_final', '1858'),
#                             ('entry_num_start1', 1146),
#                             ('entry_num', 1145)]))]),
#  OrderedDict([('id', 'rec29LbakrbDgk6jM'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0488'),
#                             ('full_text',
#                              'Military reports from Hungary. [G] (D) 1849: Mar 19. (P) Mar 20, in NRZ. N/s. (Tr) MECW 9:113—20. (4-4-) Not in MEW. -► Context in 49:15.'),
#                             ('num_chron_refs', 0),
#                             ('any_date', True),
#                             ('dated_day', '19'),
#                             ('reg_section', 'E'),
#                             ('published', 'Mar 20, in NRZ. N/s.'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acad8e)'),
#                             ('ent_num', 488),
#                             ('dated', '1849: Mar 19.'),
#                             ('month_combined', 'Mar'),
#                             ('translation',
#                              'MECW 9:113—20. (4-4-) Not in MEW. -► Context in 49:15.'),
#                             ('dated_month', 'Mar'),
#                             ('day_combined', '19'),
#                             ('dated_year', 1849),
#                             ('title', 'Military reports from Hungary.'),
#                             ('year_combined', '1849'),
#                             ('lang_orig', ['German']),
#                             ('year_final', '1849'),
#                             ('entry_num_start1', 508),
#                             ('entry_num', 507)]))]),
#  OrderedDict([('id', 'rec2B8jjvwzHUZeDE'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'E0540'),
#                             ('full_text',
#                              'On certain peculiarities in England’s economic and political development. [G] Über einige Besonderheiten der ökonomischen und politischen Entwicklung Englands. (W) 1892: Sep 12. as a ms note prob intended fora new German edn of #E171 (The condition of the working class in England). N/t. (S) MEW 22:331; title conferred. (Tr) ST/ME5 (AB) 409; %ST/ME44b (OB) 529. -♦ 92:49.'),
#                             ('num_chron_refs', 0),
#                             ('written',
#                              '1892: Sep 12. as a ms note prob intended fora new German edn of #E171 (The condition of the working class in England). N/t.'),
#                             ('reg_section', 'E'),
#                             ('mongo_id', 'ObjectId(630af2b05e934cb195acadcb)'),
#                             ('ent_num', 540),
#                             ('translation',
#                              'ST/ME5 (AB) 409; %ST/ME44b (OB) 529. -♦ 92:49.'),
#                             ('title',
#                              'On certain peculiarities in England’s economic and political development.'),
#                             ('german_title',
#                              'Über einige Besonderheiten der ökonomischen und politischen Entwicklung Englands.'),
#                             ('source', 'MEW 22:331; title conferred.'),
#                             ('lang_orig', ['German']),
#                             ('entry_num_start1', 561),
#                             ('entry_num', 560)]))]),
#  OrderedDict([('id', 'rec2B8po2sBeDKgvJ'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'ME0190'),
#                             ('full_text',
#                              'Vienna and Frankfurt. [G] Wien und Frankfurt. (W) By M/E; authorship not ascribed. (D) 1849: Mar 12. (P) Mar 13, in NRZ. N/s. (S) MEW 6:336-38. (Tr) MECW 9:47. —>49:15.'),
#                             ('num_chron_refs', 1),
#                             ('any_date', True),
#                             ('written', 'By M/E; authorship not ascribed.'),
#                             ('dated_day', '12'),
#                             ('reg_section', 'ME'),
#                             ('published', 'Mar 13, in NRZ. N/s.'),
#                             ('mongo_id', 'ObjectId(630af2b45e934cb195acb3fd)'),
#                             ('ent_num', 190),
#                             ('dated', '1849: Mar 12.'),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Mar'),
#                             ('pub_day', '13'),
#                             ('translation', 'MECW 9:47. —>49:15.'),
#                             ('dated_month', 'Mar'),
#                             ('day_combined', '12'),
#                             ('dated_year', 1849),
#                             ('pub_month', 'Mar'),
#                             ('pub_year', 1849),
#                             ('title', 'Vienna and Frankfurt.'),
#                             ('german_title', 'Wien und Frankfurt.'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1849'),
#                             ('chron_refs_text', '["recWIsVX6LBzrWUlC"]'),
#                             ('sampled', 'true'),
#                             ('source', 'MEW 6:336-38.'),
#                             ('lang_orig', ['German']),
#                             ('type', ['Journalism']),
#                             ('chron_refs', ['recTr27LJUvEtJv7Y']),
#                             ('year_final', '1849'),
#                             ('entry_num_start1', 2172),
#                             ('entry_num', 2171)]))]),
#  OrderedDict([('id', 'rec2CH0LnS1dIPZpC'),
#               ('createdTime', '2022-09-28T21:54:22.000Z'),
#               ('fields',
#                OrderedDict([('entry_id', 'M0732'),
#                             ('full_text',
#                              'Remarks on the article by M. Adolphe Bartels. [Fr] Remarques à l’article de M. Adolphe Bartels. (W) 1847: Dec c.17. (P) Dec 19, in DBZ, although in French. N/t. Signed. (S) MEGA I, 6:370; conferred title as at head. (Tr) MECW 6:402; %ST/M83 (Pad/5) 95. (++) In MEW 4:419-20. ->47:55.'),
#                             ('num_chron_refs', 1),
#                             ('any_date', True),
#                             ('writing_start_month', 'Dec'),
#                             ('written', '1847: Dec c.17.'),
#                             ('reg_section', 'M'),
#                             ('published',
#                              'Dec 19, in DBZ, although in French. N/t. Signed.'),
#                             ('mongo_id', 'ObjectId(630af2b35e934cb195acb268)'),
#                             ('ent_num', 732),
#                             ('french_title',
#                              'Remarques à l’article de M. Adolphe Bartels.'),
#                             ('scraped', 'true'),
#                             ('month_combined', 'Dec'),
#                             ('more_info', 'In MEW 4:419-20. ->47:55.'),
#                             ('writing_start_day', '17'),
#                             ('translation', 'MECW 6:402; %ST/M83 (Pad/5) 95.'),
#                             ('day_combined', '17'),
#                             ('writing_start_year', 1847),
#                             ('title',
#                              'Remarks on the article by M. Adolphe Bartels.'),
#                             ('writing_start_approx', 'true'),
#                             ('M_involved', 'true'),
#                             ('year_combined', '1847'),
#                             ('chron_refs_text', '["rec9lmfVxKLfjwMYa"]'),
#                             ('sampled', 'true'),
#                             ('source',
#                              'MEGA I, 6:370; conferred title as at head.'),
#                             ('lang_orig', ['French']),
#                             ('type', ['Journalism']),
#                             ('mew_vol', '4'),
#                             ('mew_pgs', '419-420'),
#                             ('mecw_vol', '6'),
#                             ('mecw_pgs', '402'),
#                             ('chron_refs', ['recEMNHRjcBCkL5fu']),
#                             ('mega1_vol', 'I/6'),
#                             ('mega1_pgs', '370'),
#                             ('year_final', '1847'),
#                             ('entry_num_start1', 1713),
#                             ('entry_num', 1712)]))])]

# %%
chron_result.keys()
# Out:
# odict_keys(['records', 'offset'])

# %%
chron_result['offset']
# Out:
# 'itrmiFtEds3gybqk6/rec2CH0LnS1dIPZpC'

# %%
all_entries = []
# Basically for entries with more than one event, extend the ID so that it's like 48_33.0, 48_33.1, etc.
subentry_counts = {}
for cur_record in tqdm(at.iterate(table_name)):
    cur_fields = cur_record['fields']
    cur_entry_data = {
        'at_id': cur_record['id'],
        'at_created': cur_record['createdTime']
    }
    #print(cur_record.keys())
    #print(cur_fields.keys())
    #numeric_id = cur_fields['id']
    entry_id = cur_fields['entry_id']
    entry_id_base = "_".join(entry_id.split("_")[0:2])
    #print(entry_id_base)
    #cyclo_id = cur_fields['ME_Cyclopedia_id']
    #print(numeric_id, entry_id, cyclo_id)
    cur_entry_data['entry_id'] = entry_id
    cur_entry_data['entry_id_base'] = entry_id_base
    # And now check the subentry dict
    if entry_id_base not in subentry_counts:
        # New entry id
        subentry_counts[entry_id_base] = 0
    else:
        subentry_counts[entry_id_base] = subentry_counts[entry_id_base] + 1
    entry_id_full = f"{entry_id_base}.{subentry_counts[entry_id_base]}"
    #print(entry_id_full)
    cur_entry_data['entry_id_full'] = entry_id_full
    all_entries.append(cur_entry_data)
# Out:
# 7445it [00:39, 189.17it/s]

# %%
len(all_entries)
# Out:
# 7445

# %%
joblib.dump(all_entries, "at_entries.pkl")
# Out:
# ['at_entries.pkl']

# %%
# Now get rid of the .0 for entries with only one subentry

# %%
single_entries = [k for k,v in subentry_counts.items() if v == 1]

# %%
len(single_entries)
# Out:
# 671

# %%
for cur_entry in single_entries:
    print(cur_entry)
    break
# Out:
# 65_55

# %%
all_entries[:5]
# Out:
# [{'at_id': 'rec00WLmO0M3GMg8P',
#   'at_created': '2020-12-17T01:44:33.000Z',
#   'entry_id': '48_33_739',
#   'entry_id_base': '48_33',
#   'entry_id_full': '48_33.0'},
#  {'at_id': 'rec00bY5ogUHtBRV9',
#   'at_created': '2020-12-17T01:44:33.000Z',
#   'entry_id': '65_55_2976',
#   'entry_id_base': '65_55',
#   'entry_id_full': '65_55.0'},
#  {'at_id': 'rec00egTfaoHNVRi8',
#   'at_created': '2020-12-23T13:34:59.000Z',
#   'entry_id': '93_42_6218',
#   'entry_id_base': '93_42',
#   'entry_id_full': '93_42.0'},
#  {'at_id': 'rec01gGWC4uAohMl8',
#   'at_created': '2020-12-17T01:44:33.000Z',
#   'entry_id': '56_4_2036',
#   'entry_id_base': '56_4',
#   'entry_id_full': '56_4.0'},
#  {'at_id': 'rec02OW32X4PtAchT',
#   'at_created': '2020-12-17T01:44:33.000Z',
#   'entry_id': '37_13_74',
#   'entry_id_base': '37_13',
#   'entry_id_full': '37_13.0'}]

# %%
for entry_index in range(len(all_entries)):
    cur_entry = all_entries[entry_index]
    cur_id_base = cur_entry['entry_id_base']
    if cur_id_base in single_entries:
        # Only one entry, so remove the .0
        all_entries[entry_index]['entry_id_clean'] = cur_id_base
    else:
        all_entries[entry_index]['entry_id_clean'] = all_entries[entry_index]['entry_id_full']

# %%
all_entries[:5]
# Out:
# [{'at_id': 'rec00WLmO0M3GMg8P',
#   'at_created': '2020-12-17T01:44:33.000Z',
#   'entry_id': '48_33_739',
#   'entry_id_base': '48_33',
#   'entry_id_full': '48_33.0',
#   'entry_id_clean': '48_33.0'},
#  {'at_id': 'rec00bY5ogUHtBRV9',
#   'at_created': '2020-12-17T01:44:33.000Z',
#   'entry_id': '65_55_2976',
#   'entry_id_base': '65_55',
#   'entry_id_full': '65_55.0',
#   'entry_id_clean': '65_55'},
#  {'at_id': 'rec00egTfaoHNVRi8',
#   'at_created': '2020-12-23T13:34:59.000Z',
#   'entry_id': '93_42_6218',
#   'entry_id_base': '93_42',
#   'entry_id_full': '93_42.0',
#   'entry_id_clean': '93_42.0'},
#  {'at_id': 'rec01gGWC4uAohMl8',
#   'at_created': '2020-12-17T01:44:33.000Z',
#   'entry_id': '56_4_2036',
#   'entry_id_base': '56_4',
#   'entry_id_full': '56_4.0',
#   'entry_id_clean': '56_4'},
#  {'at_id': 'rec02OW32X4PtAchT',
#   'at_created': '2020-12-17T01:44:33.000Z',
#   'entry_id': '37_13_74',
#   'entry_id_base': '37_13',
#   'entry_id_full': '37_13.0',
#   'entry_id_clean': '37_13.0'}]

# %% [markdown]
# ## Part 2: Now add at_id, at_created, entry_id_base, and entry_id_clean to mongo

# %%
import os

import dotenv
from pymongo import MongoClient

client = MongoClient()

# %%
os.path.basename(os.getcwd())
# Out:
# 'mongo'

# %%
if os.path.basename(os.getcwd()) != "marxdb":
    # Change into the dir that has the .env file
    os.chdir("..")

# %%
dotenv.load_dotenv(".env")
# Out:
# True

# %%
mongo_pw = os.getenv("MONGO_ADMIN_PW")
conn_str = f"mongodb+srv://admin:{mongo_pw}@cluster0.cg6nz.mongodb.net/test"

# %%
client = MongoClient(conn_str, connect=False)

# %%
db = client['marxdb']
coll = db['register']

# %%
for cur_entry in all_entries:
    print(cur_entry)
    break
# Out:
# {'at_id': 'rec00WLmO0M3GMg8P', 'at_created': '2020-12-17T01:44:33.000Z', 'entry_id': '48_33_739', 'entry_id_base': '48_33', 'entry_id_full': '48_33.0', 'entry_id_clean': '48_33.0'}

# %%
all_results = coll.find()

# %%
def get_at_result(entry_id):
    results = [entry for entry in all_entries if entry['entry_id'] == entry_id]
    if len(results) < 1:
        raise Exception(f"Entry {entry_id} not found in AT results")
    if len(results) > 1:
        raise Exception(f"Multiple AT results for {entry_id}")
    return results[0]

# %%
result_iter = tqdm(all_results)
for cur_result in result_iter:
    mongo_id = cur_result['_id']
    mongo_entry_id = cur_result['entry_id']
    result_iter.set_description(mongo_entry_id)
    #print(mongo_entry_id)
    at_record = get_at_result(mongo_entry_id)
    #print(at_record)
    new_fields = {
        'at_id': at_record['at_id'],
        'at_created': at_record['at_created'],
        'entry_id_base': at_record['entry_id_base'],
        'entry_id_clean': at_record['entry_id_clean']
    }
    update_one_result = coll.update_one({'_id': mongo_id}, {'$set': new_fields})
    #print(update_one_result.modified_count)
# Out:
# 95_37_6455: : 7445it [24:31,  5.06it/s]
